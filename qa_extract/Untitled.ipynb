# %%
from llama_index.core import Settings
# import chromadb
# from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
# from llama_index.vector_stores.chroma import ChromaVectorStore
# from llama_index.core import StorageContext
# from llama_index.core.llms import ChatMessage, MessageRole
# from llama_index.core.prompts import ChatPromptTemplate
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from llama_index.core import Settings
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\llama_index\core\__init__.py:19
#      15 from llama_index.core.embeddings.mock_embed_model import MockEmbedding
#      17 # indices
#      18 # loading
# ---> 19 from llama_index.core.indices import (
#      20     ComposableGraph,
#      21     DocumentSummaryIndex,
#      22     GPTDocumentSummaryIndex,
#      23     GPTKeywordTableIndex,
#      24     GPTListIndex,
#      25     GPTRAKEKeywordTableIndex,
#      26     GPTSimpleKeywordTableIndex,
#      27     GPTTreeIndex,
#      28     GPTVectorStoreIndex,
#      29     KeywordTableIndex,
#      30     KnowledgeGraphIndex,
#      31     PropertyGraphIndex,
#      32     ListIndex,
#      33     RAKEKeywordTableIndex,
#      34     SimpleKeywordTableIndex,
#      35     SummaryIndex,
#      36     TreeIndex,
#      37     VectorStoreIndex,
#      38     load_graph_from_storage,
#      39     load_index_from_storage,
#      40     load_indices_from_storage,
#      41 )
#      43 # structured
#      44 from llama_index.core.indices.common.struct_store.base import (
#      45     SQLDocumentContextBuilder,
#      46 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\llama_index\core\indices\__init__.py:4
#       1 """LlamaIndex data structures."""
#       3 # indices
# ----> 4 from llama_index.core.indices.composability.graph import ComposableGraph
#       5 from llama_index.core.indices.document_summary import (
#       6     DocumentSummaryIndex,
#       7     GPTDocumentSummaryIndex,
#       8 )
#       9 from llama_index.core.indices.document_summary.base import DocumentSummaryIndex
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\llama_index\core\indices\composability\__init__.py:4
#       1 """This module contains all classes used for composing graphs over indices."""
# ----> 4 from llama_index.core.indices.composability.graph import ComposableGraph
#       6 __all__ = ["ComposableGraph"]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\llama_index\core\indices\composability\graph.py:7
#       5 from llama_index.core.base.base_query_engine import BaseQueryEngine
#       6 from llama_index.core.data_structs.data_structs import IndexStruct
# ----> 7 from llama_index.core.indices.base import BaseIndex
#       8 from llama_index.core.schema import (
#       9     IndexNode,
#      10     NodeRelationship,
#      11     ObjectType,
#      12     RelatedNodeInfo,
#      13 )
#      14 from llama_index.core.service_context import ServiceContext
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\llama_index\core\indices\base.py:12
#      10 from llama_index.core.chat_engine.types import BaseChatEngine, ChatMode
#      11 from llama_index.core.data_structs.data_structs import IndexStruct
# ---> 12 from llama_index.core.ingestion import run_transformations
#      13 from llama_index.core.llms.utils import LLMType, resolve_llm
#      14 from llama_index.core.schema import BaseNode, Document, IndexNode, TransformComponent
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\llama_index\core\ingestion\__init__.py:2
#       1 from llama_index.core.ingestion.cache import IngestionCache
# ----> 2 from llama_index.core.ingestion.pipeline import (
#       3     DocstoreStrategy,
#       4     IngestionPipeline,
#       5     arun_transformations,
#       6     run_transformations,
#       7 )
#       9 __all__ = [
#      10     "DocstoreStrategy",
#      11     "IngestionCache",
#    (...)
#      14     "arun_transformations",
#      15 ]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\llama_index\core\ingestion\pipeline.py:15
#      12 from typing import Any, Generator, List, Optional, Sequence, Union, cast
#      14 from fsspec import AbstractFileSystem
# ---> 15 from llama_index_client import (
#      16     ConfigurableDataSourceNames,
#      17     ConfigurableTransformationNames,
#      18     Pipeline,
#      19     PipelineType,
#      20     Project,
#      21     ProjectCreate,
#      22 )
#      24 from llama_index.core.constants import (
#      25     DEFAULT_APP_URL,
#      26     DEFAULT_BASE_URL,
#      27     DEFAULT_PIPELINE_NAME,
#      28     DEFAULT_PROJECT_NAME,
#      29 )
#      30 from llama_index.core.bridge.pydantic import BaseModel, Field
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\llama_index_client\__init__.py:3
#       1 # This file was auto-generated by Fern from our API Definition.
# ----> 3 from .types import (
#       4     ApiKey,
#       5     AzStorageBlobReader,
#       6     AzStorageBlobReaderFileExtractorValue,
#       7     AzureOpenAiEmbedding,
#       8     BasePromptTemplate,
#       9     BasePydanticReader,
#      10     BeautifulSoupWebReader,
#      11     ChatMessage,
#      12     CloudChromaVectorStore,
#      13     CloudPineconeVectorStore,
#      14     CloudPostgresVectorStore,
#      15     CloudQdrantVectorStore,
#      16     CloudWeaviateVectorStore,
#      17     CodeSplitter,
#      18     ConfigurableDataSinkNames,
#      19     ConfigurableDataSourceNames,
#      20     ConfigurableTransformationDefinition,
#      21     ConfigurableTransformationNames,
#      22     ConfiguredTransformationItem,
#      23     ConfiguredTransformationItemComponent,
#      24     ConfiguredTransformationItemComponentOne,
#      25     DataSink,
#      26     DataSinkComponent,
#      27     DataSinkComponentOne,
#      28     DataSinkCreate,
#      29     DataSinkCreateComponent,
#      30     DataSinkCreateComponentOne,
#      31     DataSinkDefinition,
#      32     DataSource,
#      33     DataSourceComponent,
#      34     DataSourceComponentOne,
#      35     DataSourceCreate,
#      36     DataSourceCreateComponent,
#      37     DataSourceCreateComponentOne,
#      38     DataSourceDefinition,
#      39     DataSourceLoadJobRecord,
#      40     DataSourceManagedIngestionJobRecord,
#      41     DiscordReader,
#      42     Document,
#      43     DocumentGroup,
#      44     DocumentRelationshipsValue,
#      45     EvalDataset,
#      46     EvalDatasetJobRecord,
#      47     EvalExecutionParams,
#      48     EvalExecutionParamsOverride,
#      49     EvalLlmModelData,
#      50     EvalQuestion,
#      51     EvalQuestionCreate,
#      52     EvalQuestionResult,
#      53     ExternallyStoredComponent,
#      54     FilterCondition,
#      55     FilterOperator,
#      56     GcsReader,
#      57     GcsReaderFileExtractorValue,
#      58     GoogleDocsReader,
#      59     GoogleDriveReader,
#      60     GoogleDriveReaderFileExtractorValue,
#      61     GoogleSheetsReader,
#      62     HtmlNodeParser,
#      63     HttpValidationError,
#      64     JobNames,
#      65     JsonNodeParser,
#      66     LlamaParseSupportedFileExtensions,
#      67     Llm,
#      68     LoadedFile,
#      69     LoadedFilePayload,
#      70     LocalEval,
#      71     LocalEvalResults,
#      72     LocalEvalSets,
#      73     ManagedIngestionStatus,
#      74     MarkdownElementNodeParser,
#      75     MarkdownNodeParser,
#      76     MessageRole,
#      77     MetadataFilter,
#      78     MetadataFilterValue,
#      79     MetadataFilterValueItem,
#      80     MetadataFilters,
#      81     MetadataFiltersFiltersItem,
#      82     MetricResult,
#      83     NodeParser,
#      84     NotionPageReader,
#      85     ObjectType,
#      86     OneDriveReader,
#      87     OneDriveReaderFileExtractorValue,
#      88     OpenAiEmbedding,
#      89     ParserLanguages,
#      90     ParsingHistoryItem,
#      91     ParsingJob,
#      92     ParsingJobMarkdownResult,
#      93     ParsingJobTextResult,
#      94     ParsingUsage,
#      95     Pipeline,
#      96     PipelineCreate,
#      97     PipelineManagedIngestionJobRecord,
#      98     PipelineType,
#      99     PlatformTextNode,
#     100     PlatformTextNodeRelationshipsValue,
#     101     PlaygroundJobRecord,
#     102     PresetRetrievalParams,
#     103     PresignedUrl,
#     104     Project,
#     105     ProjectCreate,
#     106     PromptMixinPrompts,
#     107     PromptSpec,
#     108     PydanticProgramMode,
#     109     RawFile,
#     110     RawFileManagedIngestionJobRecord,
#     111     ReaderConfig,
#     112     RelatedNodeInfo,
#     113     RetrieveResults,
#     114     RssReader,
#     115     S3Reader,
#     116     S3ReaderFileExtractorValue,
#     117     SentenceSplitter,
#     118     SharePointReader,
#     119     SharePointReaderFileExtractorValue,
#     120     SimpleFileNodeParser,
#     121     SimpleWebPageReader,
#     122     SlackReader,
#     123     StatusEnum,
#     124     SupportedEvalLlmModel,
#     125     SupportedEvalLlmModelNames,
#     126     TextNode,
#     127     TextNodeRelationshipsValue,
#     128     TextNodeWithScore,
#     129     TokenTextSplitter,
#     130     TrafilaturaWebReader,
#     131     TransformationCategoryNames,
#     132     ValidationError,
#     133     ValidationErrorLocItem,
#     134     YoutubeTranscriptReader,
#     135 )
#     136 from .errors import UnprocessableEntityError
#     137 from .resources import (
#     138     DataSinkUpdateComponent,
#     139     DataSinkUpdateComponentOne,
#    (...)
#     151     project,
#     152 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\llama_index_client\types\__init__.py:3
#       1 # This file was auto-generated by Fern from our API Definition.
# ----> 3 from .api_key import ApiKey
#       4 from .az_storage_blob_reader import AzStorageBlobReader
#       5 from .az_storage_blob_reader_file_extractor_value import AzStorageBlobReaderFileExtractorValue
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\llama_index_client\types\api_key.py:10
#       8 try:
#       9     import pydantic
# ---> 10     if pydantic.__version__.startswith("1."):
#      11         raise ImportError
#      12     import pydantic.v1 as pydantic  # type: ignore
#
# AttributeError: module 'pydantic' has no attribute '__version__'

# %%
# pip install pydantic=="2.5.2"pip install pydantic==2.0.0
# !pip install pydantic==2.0.0
# !pip install pydantic==1.10.5
# Out:
# Collecting pydantic==1.10.5
#   Downloading pydantic-1.10.5-cp311-cp311-win_amd64.whl.metadata (144 kB)
#      ---------------------------------------- 0.0/144.5 kB ? eta -:--:--
#      ------------- ------------------------- 51.2/144.5 kB 2.6 MB/s eta 0:00:01
#      -------------------------------------- 144.5/144.5 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sumanyu.p\appdata\local\anaconda3\lib\site-packages (from pydantic==1.10.5) (4.9.0)
# Downloading pydantic-1.10.5-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.2/2.1 MB 7.6 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 6.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 5.9 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 5.7 MB/s eta 0:00:01
#    ------------------------- -------------- 1.4/2.1 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.1 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.3 MB/s eta 0:00:00
# Installing collected packages: pydantic
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.0
#     Uninstalling pydantic-2.0:
#       Successfully uninstalled pydantic-2.0
# Successfully installed pydantic-1.10.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qdrant-client 1.9.1 requires pydantic>=1.10.8, but you have pydantic 1.10.5 which is incompatible.
